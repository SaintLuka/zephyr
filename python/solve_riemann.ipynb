# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

# %% [markdown]
# fL(P) + fR(P) + uR − uL = 0

# %%
uL = 1249.39
uR = 1323.63

def fL(P):
    if P >= -302777000.000000:
        return (P - -302777000.000000) * np.sqrt(0.000439 / (P + 787140407.407407))
    else:
        return 2 * 1244.480318 / (4.400000 - 1) * (pow((P + 600000000.000000) / (-302777000.000000 + 600000000.000000), 0.386364) - 1)
    
def fR(P):
    if P >= 48.930100:
        return (P - 48.930100) * np.sqrt(0.001071 / (P + 2362.629621))
    else:
        return 2 * 1.607026 / (1.000003 - 1) * (pow((P + 2362.625847) / (48.930100 + 2362.625847), 0.000002) - 1)

# %%
uL = -142.966
uR = -140.59
def fL(P):
    if P >= 5.34596:
        return (P - 5.345960e+00) * np.sqrt(1.284520e-03 / (P + 2.530375e+01))
    else:
        return 2 * 1.984192e-01 / 4.261355e-08 * (pow((P + 2.530375e+01) / (5.345960e+00 + 2.530375e+01), 2.130677e-08)- 1)

def fR(P):
    if P >= -3.79503e+08:
        return (P - -3.795030e+08) * np.sqrt(4.558343e-04 / (P + 7.388314e+08))
    else:
        return 2 * 1.092730e+03 / 3.400000e+00 * (pow((P + 6.000000e+08) / (-3.795030e+08 + 6.000000e+08), 3.863636e-01) - 1)

# %%
Ps = np.linspace(-2.530374e+01, -15, 100, endpoint=True)
plt.figure(figsize=(10, 10))
vals = [fL(P) + fR(P) + uR - uL for P in Ps]
print(vals[5])
plt.plot(Ps, vals)
plt.grid()
plt.show()
# Out:
# 299.65633586782974
